# %% [markdown]
# # Toolbox
#
# > In this module, we develop various toolbox

# %%
#| default_exp toolbox

# %%
#| hide
import sys
sys.path.append("/notebooks/tools")
from nbdev.showdoc import *
# %matplotlib inline

# %%
#| export
from tools.dataset import Data
from fastbook import *
from rdkit import Chem
from rdkit.Chem import AllChem, DataStructs

# %%
#| export
def tanimoto(df, #pandas DataFrame with SMILES and ID columns.
                         smiles_col='SMILES', #name of the column containing the SMILES strings (default: 'SMILES').
                         id_col='ID', #name of the column containing the molecule IDs (default: 'ID').
                         target_col=None, #name of the column containing the target values (default: None).
                         radius=2, #radius of the Morgan fingerprint (default: 2).
                        ):
    """
    Calculates the Tanimoto similarity scores between all pairs of molecules in a pandas DataFrame.
    
    """

    # Convert SMILES to molecule objects
    df['Molecule'] = df[smiles_col].apply(lambda x: Chem.MolFromSmiles(x))

    # Calculate fingerprints
    df['Fingerprint'] = df['Molecule'].apply(lambda x: AllChem.GetMorganFingerprintAsBitVect(x, radius))

    # Calculate similarity scores
    similarity_scores = []
    for i in range(len(df)):
        for j in range(i+1, len(df)):
            sim_score = DataStructs.TanimotoSimilarity(df['Fingerprint'][i], df['Fingerprint'][j])
            if target_col is not None:
                similarity_scores.append((df[id_col][i], df[id_col][j], df[smiles_col][i], df[smiles_col][j], sim_score, df[target_col][i], df[target_col][j]))
            else:
                similarity_scores.append((df[id_col][i], df[id_col][j], df[smiles_col][i], df[smiles_col][j], sim_score))

    # Create a new DataFrame with the similarity scores
    if target_col is not None:
        result_df = pd.DataFrame(similarity_scores, columns=['ID1', 'ID2', 'SMILES1', 'SMILES2', 'SimilarityScore', 'Target1', 'Target2'])
    else:
        result_df = pd.DataFrame(similarity_scores, columns=['ID1', 'ID2', 'SMILES1', 'SMILES2', 'SimilarityScore'])

    # Sort by similarity score in descending order
    result_df.sort_values('SimilarityScore', ascending=False, inplace=True)
    result_df = result_df.reset_index(drop=True)

    return result_df

# %%
show_doc(tanimoto)
# Out:
# ---
#
# ### tanimoto
#
# >      tanimoto (df, smiles_col='SMILES', id_col='ID', target_col=None,
# >                radius=2)
#
# Calculates the Tanimoto similarity scores between all pairs of molecules in a pandas DataFrame.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | df |  |  | pandas DataFrame with SMILES and ID columns. |
# | smiles_col | str | SMILES | name of the column containing the SMILES strings (default: 'SMILES'). |
# | id_col | str | ID | name of the column containing the molecule IDs (default: 'ID'). |
# | target_col | NoneType | None | name of the column containing the target values (default: None). |
# | radius | int | 2 | radius of the Morgan fingerprint (default: 2). |

# %%
df = Data.get_g12d()

cols = ['ID','SMILES','IC50']

df = df[cols]

df = df.dropna(subset= 'IC50').reset_index(drop=True)

# %%
df
# Out:
#            ID  \
# 0        US_1
# 1        US_2
# 2        US_3
# 3        US_4
# 4        US_5
# ..        ...
# 700  paper_34
# 701  paper_35
# 702  paper_36
# 703  paper_37
# 704  paper_38
#
#                                                                                             SMILES  \
# 0                                 CN1CCC[C@H]1COc1nc(N2CC3CCC(C2)N3)c2cnc(cc2n1)-c1cc(O)cc2ccccc12
# 1                              CN1CCC[C@H]1COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 2                                 Cn1ccnc1CCOc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 3                                   Oc1cc(-c2ncc3c(nc(OCCc4ccccn4)nc3c2F)N2CC3CCC(C2)N3)c2ccccc2c1
# 4                                  Cn1nccc1COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# ..                                                                                             ...
# 700       FC1=C(C2=C(C=C(F)C=C3)C3=CC=C2)N=CC4=C1N=C(OCC56N(CCC6)CCC5)N=C4N7C[C@@H](CC8)N[C@@H]8C7
# 701    FC1=C(C2=C(C(F)=C(F)C=C3)C3=CC=C2)N=CC4=C1N=C(OCC56N(CCC6)CCC5)N=C4N7C[C@@H](CC8)N[C@@H]8C7
# 702  FC1=C(C2=C(C(C#C)=C(F)C=C3)C3=CC=C2)N=CC4=C1N=C(OCC56N(CCC6)CCC5)N=C4N7C[C@@H](CC8)N[C@@H]8C7
# 703   FC1=C(C2=C(C(Cl)=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OCC56N(CCC6)CCC5)N=C4N7C[C@@H](CC8)N[C@@H]8C7
# 704  FC1=C(C2=C(C(C#C)=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OCC56N(CCC6)CCC5)N=C4N7C[C@@H](CC8)N[C@@H]8C7
#
#       IC50
# 0    124.7
# 1      2.7
# 2      9.5
# 3    496.2
# 4    722.9
# ..     ...
# 700   27.0
# 701    7.0
# 702    2.0
# 703    2.0
# 704    2.0
#
# [705 rows x 3 columns]

# %%
result = tanimoto(df, target_col = 'IC50')

# %%
result
# Out:
#              ID1       ID2  \
# 0          US_26    US_461
# 1          US_18  paper_17
# 2          646_5    646_18
# 3         US_219    US_225
# 4         646_89    646_90
# ...          ...       ...
# 248155  31678_13    646_22
# 248156  31678_57    646_22
# 248157  31678_46    646_22
# 248158  31678_45    646_22
# 248159  31678_31    646_22
#
#                                                                                                              SMILES1  \
# 0                                             Oc1cc(-c2ncc3c(nc(OCCN4C[C@@H]5CC4CO5)nc3c2F)N2CC3CCC(C2)N3)c2ccccc2c1
# 1                                                      CN(C)CCOc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 2                    [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OCC23CCCN3C(CC2)COC(NC)=O)CN(CC1)C1=CC=CC2=CC=CC(=C12)CC
# 3                                   CO[C@@H]1CN2CCC[C@]2(COc2nc(N3CC4CCC(C3)N4)c3cnc(c(F)c3n2)-c2cccc3cccc(Cl)c23)C1
# 4                      ClC=1C=CC=C2C=CC=C(C12)N1CC=2N=C(N=C(C2CC1)N1C[C@H]2C/C(/[C@@H](C1)N2)=C\C#N)OC[C@H]2N(CCC2)C
# ...                                                                                                              ...
# 248155                    ClC1=C(C(=C2C=NNC2=C1)C1=C(C=2N=C(N=C(C2C=N1)NCC1(CCC1)N(C)C)OC[C@]12CCCN2C[C@@H](C1)F)F)C
# 248156             CN(C1(CCC1)CNC=1C2=C(N=C(N1)OC[C@]13CCCN3C[C@@H](C1)F)C(=C(N=C2)C2=CC(=CC1=CC=C(C(=C21)CC)F)O)F)C
# 248157   CN(C(OC[C@H]1CC[C@]2(CCCN12)COC=1N=C(C2=C(N1)C(=C(N=C2)C2=CC(=CC1=CC=C(C(=C21)CC)F)O)F)NCC2(CCC2)N(C)C)=O)C
# 248158  CN(C(OC[C@H]1CC[C@]2(CCCN12)COC=1N=C(C2=C(N1)C(=C(N=C2)C2=CC(=CC1=CC=C(C(=C21)C#C)F)O)F)NCC2(CCC2)N(C)C)=O)C
# 248159                              CN(C1(CCC1)CNC=1C2=C(N=C(N1)OCCC=1N(C=CN1)C)C(=C(N=C2)C2=CC(=CC1=CC=CC=C21)O)F)C
#
#                                                                                                         SMILES2  \
# 0         [C@@H]12OC[C@@H](N(C1)CCOC=1N=C(C3=C(N1)C(=C(N=C3)C3=CC(=CC1=CC=CC=C31)O)F)N3C[C@H]1CC[C@@H](C3)N1)C2
# 1                              FC1=C(C2=C(C=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OCCN(C)C)N=C4N5C[C@@H](CC6)N[C@@H]6C5
# 2       [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC[C@@]23CCCN3[C@H](CC2)COC(NC)=O)CN(CC1)C1=CC=CC2=CC=CC(=C12)CC
# 3                               CO[C@H]1CN2CCC[C@]2(COc2nc(N3CC4CCC(C3)N4)c3cnc(c(F)c3n2)-c2cccc3cccc(Cl)c23)C1
# 4                 ClC=1C=CC=C2C=CC=C(C12)N1CC=2N=C(N=C(C2CC1)N1C[C@H]2C/C(/[C@@H](C1)N2)=C/C#N)OC[C@H]2N(CCC2)C
# ...                                                                                                         ...
# 248155                                  [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC)CN(CC1)C1=CC=CC2=CC=CC(=C12)C
# 248156                                  [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC)CN(CC1)C1=CC=CC2=CC=CC(=C12)C
# 248157                                  [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC)CN(CC1)C1=CC=CC2=CC=CC(=C12)C
# 248158                                  [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC)CN(CC1)C1=CC=CC2=CC=CC(=C12)C
# 248159                                  [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC)CN(CC1)C1=CC=CC2=CC=CC(=C12)C
#
#         SimilarityScore  Target1  Target2
# 0              1.000000     42.1     62.0
# 1              1.000000     76.8     70.0
# 2              1.000000      1.6      2.0
# 3              1.000000      8.1      9.2
# 4              1.000000  10000.0   1462.9
# ...                 ...      ...      ...
# 248155         0.113821    165.0   7862.6
# 248156         0.112000      1.1   7862.6
# 248157         0.105263      0.7   7862.6
# 248158         0.104478      0.4   7862.6
# 248159         0.103448    856.8   7862.6
#
# [248160 rows x 7 columns]

# %%
result = result.query("SimilarityScore ==1")

# %%
result = result.copy()

# %%
result['var'] = result.apply(lambda x: abs(np.log10(x['Target1']/x['Target2'])), axis=1)

# %%
result['mean'] = result.apply(lambda x: np.nan if x['var'] > 1.5 else (x['Target1'] + x['Target2']) / 2, axis=1)

# %%
result.to_csv('tanimoto.csv',index=False)

# %% [markdown]
# Modify the tanimoto.csv, take average of 2/3/4 duplicates, if its is from paper, then ignore it when averaging

# %%
dup = pd.read_csv('IC50_duplicate.csv')

# %%
dup.rename(columns={'SMILES2':'SMILES'},inplace=True)

# %%
dup
# Out:
#          ID1       ID2  \
# 0      US_65     US_66
# 1      US_55     US_56
# 2     US_252    US_482
# 3     US_259    US_468
# 4     US_451    US_467
# ..       ...       ...
# 69     646_4    646_54
# 70     646_5    646_18
# 71   646_121   646_122
# 72    646_49   646_117
# 73  31678_11  31678_32
#
#                                                                                                                SMILES  \
# 0                                       Fc1c(ncc2c(nc(OC[C@@]34CCCN3C(CCl)CC4)nc12)N1CC2CCC(C1)N2)-c1cccc2cccc(Cl)c12
# 1                                                 OC[C@@H](O)COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cccc2cccc(Cl)c12
# 2         [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC[C@@]23CCCN3C[C@H](C2)F)C(=C(N=C1)C1=CC(=CC2=CC=C(C(=C12)C#C)F)O)F
# 3             [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC[C@@]23CCCN3C[C@H](C2)F)C(=C(N=C1)C1=CC(=CC2=CC=CC(=C12)CC)O)F
# 4   [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC[C@]23CCCN3C[C@@H](C2)F)C(=C(N=C1)C=1C=C(C=C(C1[C@@H]1[C@@H](C1)C)Cl)O)F
# ..                                                                                                                ...
# 69                          OC=1C=C(C2=CC=CC=C2C1)N1CC=2N=C(N=C(C2CC1)N1C[C@H]2C[C@H]([C@@H](C1)N2)O)OC[C@H]2N(CCC2)C
# 70            [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC[C@@]23CCCN3[C@H](CC2)COC(NC)=O)CN(CC1)C1=CC=CC2=CC=CC(=C12)CC
# 71             C(C)C2=C1C(=CC=CC1=CC=C2)N8CC3=C(C(=NC(=N3)OC[C@@]45CCCN4C[C@@H](C5)F)[C@@H]6C[C@@H]7CC[C@H](C6)N7)CC8
# 72                 [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC[C@]23CCCN3C[C@@H](C2)F)CN(CC1)C1=CC(=CC2=CC=CC(=C12)Cl)O
# 73                                 CN(C1(CCC1)CNC=1C2=C(N=C(N1)OC[C@@H]1N(CCC1)C)C(=C(N=C2)C2=CC(=CC1=CC=CC=C21)O)F)C
#
#            mean
# 0           NaN
# 1   6024.000000
# 2      1.200000
# 3      1.400000
# 4      1.333333
# ..          ...
# 69          NaN
# 70     1.800000
# 71   121.450000
# 72     0.600000
# 73   239.550000
#
# [74 rows x 4 columns]

# %%
unique_ids = set(dup['ID1']).union(set(dup['ID2']))

# %%
df[~df['ID'].isin(unique_ids)]
# Out:
#            ID  \
# 0        US_1
# 3        US_4
# 4        US_5
# 5        US_6
# 6        US_7
# ..        ...
# 675   paper_9
# 676  paper_10
# 677  paper_11
# 678  paper_12
# 680  paper_14
#
#                                                                             SMILES  \
# 0                 CN1CCC[C@H]1COc1nc(N2CC3CCC(C2)N3)c2cnc(cc2n1)-c1cc(O)cc2ccccc12
# 3                   Oc1cc(-c2ncc3c(nc(OCCc4ccccn4)nc3c2F)N2CC3CCC(C2)N3)c2ccccc2c1
# 4                  Cn1nccc1COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 5                Cc1cccnc1CCOc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 6                   Oc1cc(-c2ncc3c(nc(OCCc4ncccn4)nc3c2F)N2CC3CCC(C2)N3)c2ccccc2c1
# ..                                                                             ...
# 675       FC1=C(C2=C(C=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OC[C@H]5N(C)CCC5)N=C4N6CCOCC6
# 676    FC1=C(C2=C(C=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OC[C@H]5N(C)CCC5)N=C4N6CC(C)NCC6
# 677    FC1=C(C2=C(C=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OC[C@H]5N(C)CCC5)N=C4N6C(C)CNCC6
# 678    FC1=C(C2=C(C=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OC[C@H]5N(C)CCC5)N=C4N6CC7NCC6C7
# 680  FC1=C(C2=C(C=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OC[C@H]5N(C)CCC5)N=C4N6CC(C7)NC7C6
#
#         IC50
# 0      124.7
# 3      496.2
# 4      722.9
# 5      434.1
# 6     1867.3
# ..       ...
# 675  12000.0
# 676   2100.0
# 677   1500.0
# 678    650.0
# 680    310.0
#
# [592 rows x 3 columns]

# %%
df
# Out:
#            ID  \
# 0        US_1
# 1        US_2
# 2        US_3
# 3        US_4
# 4        US_5
# ..        ...
# 700  paper_34
# 701  paper_35
# 702  paper_36
# 703  paper_37
# 704  paper_38
#
#                                                                                             SMILES  \
# 0                                 CN1CCC[C@H]1COc1nc(N2CC3CCC(C2)N3)c2cnc(cc2n1)-c1cc(O)cc2ccccc12
# 1                              CN1CCC[C@H]1COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 2                                 Cn1ccnc1CCOc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 3                                   Oc1cc(-c2ncc3c(nc(OCCc4ccccn4)nc3c2F)N2CC3CCC(C2)N3)c2ccccc2c1
# 4                                  Cn1nccc1COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# ..                                                                                             ...
# 700       FC1=C(C2=C(C=C(F)C=C3)C3=CC=C2)N=CC4=C1N=C(OCC56N(CCC6)CCC5)N=C4N7C[C@@H](CC8)N[C@@H]8C7
# 701    FC1=C(C2=C(C(F)=C(F)C=C3)C3=CC=C2)N=CC4=C1N=C(OCC56N(CCC6)CCC5)N=C4N7C[C@@H](CC8)N[C@@H]8C7
# 702  FC1=C(C2=C(C(C#C)=C(F)C=C3)C3=CC=C2)N=CC4=C1N=C(OCC56N(CCC6)CCC5)N=C4N7C[C@@H](CC8)N[C@@H]8C7
# 703   FC1=C(C2=C(C(Cl)=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OCC56N(CCC6)CCC5)N=C4N7C[C@@H](CC8)N[C@@H]8C7
# 704  FC1=C(C2=C(C(C#C)=CC=C3)C3=CC(O)=C2)N=CC4=C1N=C(OCC56N(CCC6)CCC5)N=C4N7C[C@@H](CC8)N[C@@H]8C7
#
#       IC50
# 0    124.7
# 1      2.7
# 2      9.5
# 3    496.2
# 4    722.9
# ..     ...
# 700   27.0
# 701    7.0
# 702    2.0
# 703    2.0
# 704    2.0
#
# [705 rows x 3 columns]

# %%
pd.concat([df, dup.rename(columns={'ID2': 'ID', 'mean': 'IC50'})])
# Out:
#           ID  \
# 0       US_1
# 1       US_2
# 2       US_3
# 3       US_4
# 4       US_5
# ..       ...
# 69    646_54
# 70    646_18
# 71   646_122
# 72   646_117
# 73  31678_32
#
#                                                                                                      SMILES  \
# 0                                          CN1CCC[C@H]1COc1nc(N2CC3CCC(C2)N3)c2cnc(cc2n1)-c1cc(O)cc2ccccc12
# 1                                       CN1CCC[C@H]1COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 2                                          Cn1ccnc1CCOc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 3                                            Oc1cc(-c2ncc3c(nc(OCCc4ccccn4)nc3c2F)N2CC3CCC(C2)N3)c2ccccc2c1
# 4                                           Cn1nccc1COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# ..                                                                                                      ...
# 69                OC=1C=C(C2=CC=CC=C2C1)N1CC=2N=C(N=C(C2CC1)N1C[C@H]2C[C@H]([C@@H](C1)N2)O)OC[C@H]2N(CCC2)C
# 70  [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC[C@@]23CCCN3[C@H](CC2)COC(NC)=O)CN(CC1)C1=CC=CC2=CC=CC(=C12)CC
# 71   C(C)C2=C1C(=CC=CC1=CC=C2)N8CC3=C(C(=NC(=N3)OC[C@@]45CCCN4C[C@@H](C5)F)[C@@H]6C[C@@H]7CC[C@H](C6)N7)CC8
# 72       [C@H]12CN(C[C@H](CC1)N2)C=2C1=C(N=C(N2)OC[C@]23CCCN3C[C@@H](C2)F)CN(CC1)C1=CC(=CC2=CC=CC(=C12)Cl)O
# 73                       CN(C1(CCC1)CNC=1C2=C(N=C(N1)OC[C@@H]1N(CCC1)C)C(=C(N=C2)C2=CC(=CC1=CC=CC=C21)O)F)C
#
#       IC50       ID1
# 0   124.70       NaN
# 1     2.70       NaN
# 2     9.50       NaN
# 3   496.20       NaN
# 4   722.90       NaN
# ..     ...       ...
# 69     NaN     646_4
# 70    1.80     646_5
# 71  121.45   646_121
# 72    0.60    646_49
# 73  239.55  31678_11
#
# [779 rows x 4 columns]

# %%
#| hide
import nbdev; nbdev.nbdev_export()
