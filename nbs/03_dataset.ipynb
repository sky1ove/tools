# %% [markdown]
# # Dataset
#
# > A collection of datasets

# %%
#| default_exp dataset

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
from fastbook import *

# %%
#| export
def get_antibiotics():
    "Deduplicated dataset from the cell paper: A Deep Learning Approach to Antibiotic Discovery"
    df = pd.read_csv("https://github.com/sky1ove/tools/raw/main/dataset/antibiotics_2335.csv")
    print(df.shape, df.columns.tolist())
    return df

# %%
show_doc(get_antibiotics)
# Out:
# ---
#
# ### get_antibiotics
#
# >      get_antibiotics ()
#
# Deduplicated dataset from the cell paper: A Deep Learning Approach to Antibiotic Discovery

# %%
get_antibiotics()
# Out:
# (2335, 4) ['name', 'SMILES', 'inhibition', 'activity']
#                                name  \
# 0                       CEFPIRAMIDE
# 1             GEMIFLOXACIN MESYLATE
# 2               POLYMYXIN B SULFATE
# 3           PRAXADINE HYDROCHLORIDE
# 4     CHLORHEXIDINE DIHYDROCHLORIDE
# ...                             ...
# 2330                      COLFORSIN
# 2331               ANAZOLENE SODIUM
# 2332                        DAPSONE
# 2333                     EVANS BLUE
# 2334          PROTOPORPHYRINOGEN IX
#
#                                                                                                                                                               SMILES  \
# 0                                                                                      Cc1cc(O)c(C(=O)NC(C(=O)NC2C(=O)N3C(C(=O)O)=C(CSc4nnnn4C)CSC23)c2ccc(O)cc2)cn1
# ...

# %%
#| export
def get_g12d():
    "Dataset from paper"
    df = pd.read_csv("https://github.com/sky1ove/tools/raw/main/dataset/KRASi_g12d.csv")
    print(df.shape, df.columns.tolist())
    return df

# %%
get_g12d() #may add sources col later
# Out:
# (722, 10) ['ID', 'SMILES', 'group', 'with_3F', 'racemic_trans', 'mixture_isomer', 'trans', 'Kd', 'IC50', 'erk_IC50']
#            ID  \
# 0        US_1
# 1        US_2
# 2        US_3
# 3        US_4
# 4        US_5
# ..        ...
# 717  paper_34
# 718  paper_35
# 719  paper_36
# 720  paper_37
# 721  paper_38
#
#                                                                                             SMILES  \
# 0                                 CN1CCC[C@H]1COc1nc(N2CC3CCC(C2)N3)c2cnc(cc2n1)-c1cc(O)cc2ccccc12
# 1                              CN1CCC[C@H]1COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 2                                 Cn1ccnc1CCOc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# 3                                   Oc1cc(-c2ncc3c(nc(OCCc4ccccn4)nc3c2F)N2CC3CCC(C2)N3)c2ccccc2c1
# 4                                  Cn1nccc1COc1nc(N2CC3CCC(C2)N3)c2cnc(c(F)c2n1)-c1cc(O)cc2ccccc12
# ...

# %%
#| hide
import nbdev; nbdev.nbdev_export()
